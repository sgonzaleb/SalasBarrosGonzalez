# %% [markdown]
# # Carga y Visualización de la Base de Datos Limpia
# **Proyecto:** Rendimiento de Delanteros del Big Six y Sentimiento en Redes Sociales
# **Curso:** COM-208

# %%
import pandas as pd

# Cargamos el dataset limpio desde el archivo CSV
url = '../delanteros_premier_sentimiento_limpio.csv'
df = pd.read_csv(url)

# Visualizamos las primeras filas
df.head()

# %%
# Resumen de variables y tipos de datos
df.info()
